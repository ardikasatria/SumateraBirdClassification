# %%
import os
import glob
import pandas as pd

# %%
corepath="/content/drive/MyDrive/Download_Birds_Data/"

# %%
df = pd.read_csv('/content/drive/MyDrive/Download_Birds_Data/birds_metadata.csv')

# %%
df.head()
# Out:
#        id        gen  ... bird-seen playback-used
# 0  665786  Dryocopus  ...        no            no
# 1  656517  Dryocopus  ...        no            no
# 2  649669  Dryocopus  ...       yes            no
# 3  629324  Dryocopus  ...       yes            no
# 4  620581  Dryocopus  ...       yes            no
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1749 entries, 0 to 1748
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1749 non-null   int64
#  1   gen            1749 non-null   object
#  2   sp             1749 non-null   object
#  3   ssp            618 non-null    object
#  4   en             1749 non-null   object
#  5   rec            1749 non-null   object
#  6   cnt            1749 non-null   object
#  7   loc            1749 non-null   object
#  8   lat            1693 non-null   float64
#  9   lng            1693 non-null   float64
#  10  alt            1606 non-null   object
#  11  type           1749 non-null   object
#  12  url            1749 non-null   object
#  13  file           1749 non-null   object
#  14  file-name      1749 non-null   object
#  15  sono           1749 non-null   object
#  16  lic            1749 non-null   object
# ...

# %%
df.describe()
# Out:
#                   id          lat          lng
# count    1749.000000  1693.000000  1693.000000
# mean   311462.411092     9.771394    91.058220
# std    187743.278942    14.158000    40.443772
# min     18866.000000   -33.268100   -16.781500
# 25%    150968.000000     1.510500    96.485000
# 50%    342690.000000     4.976700   103.791300
# 75%    445750.000000    14.510100   115.497100
# max    677153.000000    45.894200   153.218100

# %%
# num unique classes
df['en'].nunique()
# Out:
# 15

# %%
df['en'].value_counts()
# Out:
# Black-winged Kite               256
# Pygmy Cupwing                   214
# Large-tailed Nightjar           190
# White-bellied Woodpecker        128
# Greater Racket-tailed Drongo    124
# Rufous-tailed Tailorbird        122
# Slender-billed Crow             122
# Horsfield's Babbler             108
# Sooty-capped Babbler             86
# Oriental Pied Hornbill           84
# Spectacled Bulbul                79
# Mangrove Whistler                73
# Rufous-browed Flycatcher         57
# Olive-winged Bulbul              54
# Short-tailed Babbler             52
# Name: en, dtype: int64

# %%
sum(df['en'].value_counts() >= 100) / df['en'].nunique()
# Out:
# 0.5333333333333333

# %%
sum(df['en'].value_counts() <= 100) / df['en'].nunique()
# Out:
# 0.4666666666666667

# %%
df['q'].value_counts()
# Out:
# A           880
# B           563
# C           176
# no score    106
# D            20
# E             4
# Name: q, dtype: int64

# %%
df.shape
# Out:
# (1749, 26)

# %%
df[df.q.isin(['D', 'E'])]
# Out:
#           id            gen  ... bird-seen playback-used
# 126   123016      Dryocopus  ...        no            no
# 127   342628      Dryocopus  ...       yes            no
# 311   600097    Caprimulgus  ...        no            no
# 312   535359    Caprimulgus  ...        no            no
# 313   359616    Caprimulgus  ...   unknown       unknown
# 314   301095    Caprimulgus  ...        no            no
# 315    67852    Caprimulgus  ...   unknown       unknown
# 316    31542    Caprimulgus  ...   unknown       unknown
# 317    31541    Caprimulgus  ...   unknown       unknown
# 530   178456       Pnoepyga  ...       yes           yes
# 531   326312       Pnoepyga  ...       yes            no
# 815   569726     Pycnonotus  ...        no            no
# 816   182037     Pycnonotus  ...        no            no
# 1010   56341   Malacopteron  ...        no            no
# 1532  651042         Elanus  ...       yes            no
# ...

# %% [markdown]
# delete audio with q= D & E manually

# %%
df1 = df.drop([126, 127, 311, 312, 313, 314,
               315, 316, 317, 530, 531, 815,
               816, 1010, 1532, 1533, 1534, 1535,
               1536, 1537, 1538, 1539, 1540, 1624])

# %%
df1.shape
# Out:
# (1725, 26)

# %%
df1.to_csv(corepath + 'birdmetadata_1.csv')

# %%
blist=[]
for root, dirs, files in os.walk(corepath):
    for file in files:
        if file.endswith(".wav"):
            blist.append(os.path.join(root, file))
                
print('Found ', len(blist),' files.')
# Out:
# Found  1724  files.
