# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import seaborn as sns
from keras.preprocessing import image
from tensorflow.keras.models import load_model

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = False)

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Birddata_split/melspec8_1/train/',
                                                 target_size = (64, 64),
                                                 shuffle=True)
# Out:
# Found 10813 images belonging to 15 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Birddata_split/melspec8_1/val/',
                                            target_size = (64, 64),
                                            shuffle=False)
# Out:
# Found 1319 images belonging to 15 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(64, 64, 3)),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(15, activation='softmax')
])

# %%
from keras.callbacks import History 
history = History()

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001, momentum=0.9)

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 62, 62, 32)        896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 62, 62, 32)        128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 60, 60, 32)        9248
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 60, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 26, 26, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 13, 13, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 21632)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               11076096
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 15)                1935
# =================================================================
# Total params: 11,249,775
# Trainable params: 11,247,983
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, show_shapes=True, show_layer_names = True)
from IPython.display import Image
Image(filename='model.png')

# %%
History = model.fit(training_set, validation_data = test_set, batch_size=32,epochs=50,callbacks=[history])
# Out:
# Epoch 1/50
# 338/338 [==============================] - 806s 2s/step - loss: 3.4780 - accuracy: 0.1495 - val_loss: 3.4884 - val_accuracy: 0.1463
# Epoch 2/50
# 338/338 [==============================] - 351s 1s/step - loss: 2.9146 - accuracy: 0.2203 - val_loss: 2.3576 - val_accuracy: 0.2782
# Epoch 3/50
# 338/338 [==============================] - 356s 1s/step - loss: 2.6522 - accuracy: 0.2589 - val_loss: 2.1332 - val_accuracy: 0.3525
# Epoch 4/50
# 338/338 [==============================] - 370s 1s/step - loss: 2.4781 - accuracy: 0.2891 - val_loss: 2.1943 - val_accuracy: 0.3366
# Epoch 5/50
# 338/338 [==============================] - 377s 1s/step - loss: 2.3678 - accuracy: 0.3167 - val_loss: 2.0537 - val_accuracy: 0.3662
# Epoch 6/50
# 338/338 [==============================] - 360s 1s/step - loss: 2.2698 - accuracy: 0.3364 - val_loss: 1.9246 - val_accuracy: 0.3897
# Epoch 7/50
# 338/338 [==============================] - 364s 1s/step - loss: 2.1930 - accuracy: 0.3497 - val_loss: 1.8939 - val_accuracy: 0.4041
# Epoch 8/50
# 338/338 [==============================] - 375s 1s/step - loss: 2.1653 - accuracy: 0.3566 - val_loss: 2.0029 - val_accuracy: 0.3980
# Epoch 9/50
# 338/338 [==============================] - 410s 1s/step - loss: 2.0666 - accuracy: 0.3852 - val_loss: 1.8658 - val_accuracy: 0.4238
# Epoch 10/50
# 338/338 [==============================] - 406s 1s/step - loss: 2.0265 - accuracy: 0.3869 - val_loss: 1.7832 - val_accuracy: 0.4466
# Epoch 11/50
# 338/338 [==============================] - 405s 1s/step - loss: 1.9604 - accuracy: 0.4061 - val_loss: 1.7384 - val_accuracy: 0.4443
# Epoch 12/50
# 338/338 [==============================] - 375s 1s/step - loss: 1.9357 - accuracy: 0.4055 - val_loss: 1.7200 - val_accuracy: 0.4458
# Epoch 13/50
# 338/338 [==============================] - 368s 1s/step - loss: 1.8928 - accuracy: 0.4220 - val_loss: 1.7624 - val_accuracy: 0.4268
# Epoch 31/50
# 338/338 [==============================] - 334s 988ms/step - loss: 1.5006 - accuracy: 0.5324 - val_loss: 1.4544 - val_accuracy: 0.5406
# Epoch 32/50
# 338/338 [==============================] - 355s 1s/step - loss: 1.4742 - accuracy: 0.5386 - val_loss: 1.4533 - val_accuracy: 0.5489
# Epoch 33/50
# 338/338 [==============================] - 344s 1s/step - loss: 1.4749 - accuracy: 0.5332 - val_loss: 1.8295 - val_accuracy: 0.4663
# Epoch 34/50
# 338/338 [==============================] - 339s 1s/step - loss: 1.4861 - accuracy: 0.5332 - val_loss: 1.8060 - val_accuracy: 0.4564
# Epoch 35/50
# 338/338 [==============================] - 334s 988ms/step - loss: 1.4379 - accuracy: 0.5497 - val_loss: 1.5082 - val_accuracy: 0.5337
# Epoch 36/50
# 338/338 [==============================] - 337s 995ms/step - loss: 1.4292 - accuracy: 0.5496 - val_loss: 1.4143 - val_accuracy: 0.5451
# Epoch 37/50
# 338/338 [==============================] - 337s 995ms/step - loss: 1.4226 - accuracy: 0.5505 - val_loss: 1.4541 - val_accuracy: 0.5368
# Epoch 38/50
# 338/338 [==============================] - 337s 998ms/step - loss: 1.4092 - accuracy: 0.5602 - val_loss: 1.5007 - val_accuracy: 0.5322
# Epoch 39/50
# 338/338 [==============================] - 377s 1s/step - loss: 1.3961 - accuracy: 0.5615 - val_loss: 1.5623 - val_accuracy: 0.5254
# Epoch 40/50
# 338/338 [==============================] - 349s 1s/step - loss: 1.3773 - accuracy: 0.5722 - val_loss: 1.4569 - val_accuracy: 0.5519
# Epoch 41/50
# 338/338 [==============================] - 447s 1s/step - loss: 1.3748 - accuracy: 0.5724 - val_loss: 1.5139 - val_accuracy: 0.5004
# Epoch 42/50
# 338/338 [==============================] - 427s 1s/step - loss: 1.3594 - accuracy: 0.5717 - val_loss: 2.2040 - val_accuracy: 0.4443
# Epoch 43/50
#  86/338 [======>.......................] - ETA: 6:01 - loss: 1.3188 - accuracy: 0.5901

# %%
plt.figure(figsize=(14,8))
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy', fontsize=14)
plt.ylabel('Accuracy', fontsize=12)
plt.xlabel('Epoch', fontsize=12)
plt.legend(['train', 'test'], loc='upper left')
plt.show()

 # summarize history for loss
plt.figure(figsize=(14,8))
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss', fontsize=14)
plt.ylabel('Loss',fontsize=12)
plt.xlabel('Epoch',fontsize=12)
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sns

# %%
target_names = []
for key in training_set.class_indices:
  target_names.append(key)

print(target_names)

# %%
accuracy = model.evaluate(test_set)
print('n', 'Test_Accuracy:-', accuracy[1])

# %%
pred = model.predict(test_set)
y_pred = np.argmax(pred, axis=1)
#y_true = np.argmax(pred, axis=1)
print('confusion matrix')
print(confusion_matrix(test_set.classes, y_pred))
    #confusion matrix
f, ax = plt.subplots(figsize=(14,8))
sns.heatmap(confusion_matrix(test_set.classes, y_pred), annot=True, fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
print('Classification Report')
print(classification_report(test_set.classes, y_pred, target_names=target_names ))
